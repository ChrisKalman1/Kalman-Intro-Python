# %% [markdown]
# ## Homework 1: Python Fundamentals — Understanding, Transfer, and Process
#
# **Due:** Friday, 9:00 AM

# %%
1. What is a markdown cell in jupyter notebook and how do I change a cell from a markdown cell to a code cell? Use a markdown cell type for this answer.

# %%
Your answer here (Please use a markdown cell): A markdown cell lets you write formatted text and notes in your Jupyter notebook instead of code. To switch a cell from markdown to code, you can click on it and press Y, or use the dropdown menu at the top.

# %% [markdown]
# 2. In Python, what is the difference between =(single equal) and == (double equal)? Please give an example of each.

# %%
Your answer here: A single = indicates a value to a variable (like x = 5) while a == compares two variable to check if theyre equal like (if == x==5)

# %% [markdown]
# 3. If I am commenting on my code in a cell, what are the two ways to do this in Python?

# %%
Your answer here: You can use # or ""

# %% [markdown]
# 4. Assign your name, your Yale program, and your year of graduation equal to variables of your choosing. Then write a print statement using an "f string" that says "Hello, my name is (name). I am in Yale's (program) and I hope to graduate in (year)."

# %%
#Your answer here: 
name = "Chris" 
program = "Masters of Environmental Management"
year = "2027"
print(f"Hello, my name is {name}. I am in Yale's {program} and I hope to graduate in {year}.")

# %% [markdown]
# 5. Write the mathematical operators for the following using a markdown cell type and give a code example of each:
#
# For example: plus: + , 3 + 4
#
# minus: -, 4 - 3
#
# multiply: *, 4*3
#
# divide:/, 4/3
#
# find the remainder of two numbers divided: %, 10%2
#
# square: (as in 3 squared is 9) **2, 3**2
#
# cube: (as in 2 cubed is 8) **3, 2**3
#
# greater than: >, if x > 10
#
# greater than or equal to: >=, if x>=10
#
# less than: <, if x<10
#
# less than or equal to:<=, if x<=10

# %% [markdown]
# 6. What is the built-in Python function to determine the type of an object? Give four examples of using this function on four different object types.

# %%
#Your answer here: 

type(42)

type("Hello")

type(1.24)

type(True)
# Out:
# bool

# %% [markdown]
# 7. Use the "replace" method in python so that the following occurs:
#
# greeting = "Hello there students!"
# becomes
# print(greeting)
# output: "Hello there Pythonistas!"

# %%
#your code here:
greeting = "Hello there students!"
greeting = greeting.replace("students", "Pythonistas")

# %% [markdown]
# 8.In the following code:
# agreement = "Paris Agreement"
# agreement.replace("Paris", "Moon")
# print(agreement)
#
# The output is "Paris Agreement", not "Moon Agreement"
#
# Please explain why that is the case.

# %% [markdown]
# Your answer here: The .replace() method creates a new string with your changes instead of changing the original one. Since you didn't save that new string to a variable, it just disappeared, and agreement still has the original "Paris Agreement" in it.

# %% [markdown]
# 9. Now fix the code using the replace method so that:
#    agreement = "Paris Agreement"
#    when you write:
#    print(agreement)
#    output is "Moon Agreement"

# %%
 
agreement = "Paris Agreement"
agreement = agreement.replace("Paris", "Moon")
print(agreement)
# Out:
# Moon Agreement

# %% [markdown]
# 10. Please explain why the statement returns "False" and write code that fixes the error:
#
# .3 + .3 + .3 == .9

# %%
#Your code here: This results in an error because of the way the numbers are stored and a lack of rounding: round(.3 + .3 + .3, 1) == .9

# %% [markdown]
# 11. I want to make a tip calculator. Step one:
# Please use the input method to accept an input from a user prompting them with "Please enter a price of the meal" and save
#  it to the variable "price"

# %%
#Your code here:
price = input("Please enter a price of the meal: ")

# %%
12. Here is a script I wrote for a tip calculator:
                        
price = input("Please enter the price of the meal: " )

tip = price * 0.22

total = price + tip

print("A 16% tip would be: ", tip)

print("The total including tip would be: ", total)

The problem is it throws an error! Can you look at this code and see why it is throwing an error without running it?

# %%
Your answer here: Python does not know how to multiply a text variable by a number

# %% [markdown]
# 13. Please fix the above code and run it:

# %%
#Your code here:
price = float(input("Please enter the price of the meal: "))
tip = price * 0.16
total = price + tip
print("A 16% tip would be: ", tip)
print("The total including tip would be: ", total)
# Out:
# Please enter the price of the meal:  100
# A 16% tip would be:  16.0
# The total including tip would be:  116.0

# %% [markdown]
# 14. Write a script that takes a user inputted string and checks whether if they are the following
#
# if it is all alphabets
# if it is numeric
# if it is all upper case
# if it is all lower case

# %%
#Your code here:
user_input = input("Enter a string: ")

print(f"All alphabets: {user_input.isalpha()}")
print(f"Numeric: {user_input.isnumeric()}")
print(f"All upper case: {user_input.isupper()}")
print(f"All lower case: {user_input.islower()}")
# Out:
# Enter a string:  hello
# All alphabets: True
# Numeric: False
# All upper case: False
# All lower case: True

# %%
15. Write a script that takes a user inputted target_string of your chosing and prints it out in the following three formats.

All letters capitalized - capitalize( )
All letters lowercase - lower( )
All vowels lowercase and all consonants uppercase

# %%
#Your code here
target_string = input("Please enter a string: ")

print("All capitalized:", target_string.upper())
print("All lowercase:", target_string.lower())

vowels = "aeiouAEIOU"
result = "".join(c.lower() if c in vowels else c.upper() if c.isalpha() else c for c in target_string)
print("Vowels lowercase, consonants uppercase:", result)

# %%
16. Assuming a package is not part of the Anaconda build of Python used, how would I:
a. install a package from my terminal?
b. install a package from my Jupyter notebook ?
c. import a package ? 
d. what happens when if I write "import this" but don't name a package? (run it below)

# %%
#Your code here:
#a. pip install package_name
#b. !pip install package_name
#c. import package_name
#d. Nothing seems to be happening
import this

# %%
17.statement= 'It's truly one of my favorite quotes: "Success depends on intuition, on seeing what afterwards proves to be true but cannot be established at the moment"
#To whom is the previous quote atributed?
# Out:
#   Cell In[3], line 1
#     17.statement= 'It's truly one of my favorite quotes: "Success depends on intuition, on seeing what afterwards proves to be true but cannot be established at the moment"
#       ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# Your answer here: Joseph Schumpeter

# %%
18. Copy the code above to the cell below. Run it. Why is it throwing an error? Please fix it.

# %%
#Your answer here: The single quotation mark confuses python when the apostrophe in "It's" shows up
#Your code here: 
statement = "It's truly one of my favorite quotes: \"Success depends on intuition, on seeing what afterwards proves to be true but cannot be established at the moment\""
# To whom is the previous quote attributed?

# %% [markdown]
# 19. Write code, using the strip() method  to remove the white spaces from the beginning and the end of the following and print below:

# %%
greeting = "   Hi students. What's going on?!       "
# You answer here: greeting = "   Hi students. What's going on?!   "
greeting = greeting.strip()
print(greeting)
# Out:
# Hi students. What's going on?!

# %%
20. How do you convert a string to all lowercase? Give an example.

# %%
# Your answer here: use the text.lower function
text = "HELLO WORLD"
text = text.lower()
print(text)
# Out:
# hello world

# %% [markdown]
# 21. How do you convert a string to a list in python? Give an example.

# %%
# Your answer here: 
text = "hello tire text goodbye"
text_list = text.split()
print(text_list)
# Out:
# ['hello', 'tire', 'text', 'goodbye']

# %% [markdown]
# 22.  How do you convert a string to a tuple in python? Give an example.

# %%
# Your answer here: 
text = "Hello"
text_tuple = tuple(text)
print(text_tuple)
# Out:
# ('H', 'e', 'l', 'l', 'o')

# %% [markdown]
# 23.  How do you convert a string to an int in python? Give an example.

# %%
# Your answer here: 
text = "55"
number = int(text)
print(type(number))
# Out:
# <class 'int'>
# 55
# <class 'int'>

# %% [markdown]
# 24.  How do you convert a string to a float in python? Give an example.

# %%
# Your answer here: 
text = "1.45"
number = float(text)
print(number)
print(type(number))
# Out:
# 1.45
# <class 'float'>

# %% [markdown]
# 25.  How do you capitalizes first letter of string? Give an example.

# %%
# Your answer here: 
text = "hello world"
text = text.capitalize()
print(text)
# Out:
# Hello world

# %% [markdown]
# 26. How do you check in a string that all characters are digits? Give an example.

# %%
# Your answer here: 
text = "12345"
print(text.isdigit())
# Out:
# True

# %% [markdown]
# 27.  How do you check in a string that all characters are alphanumeric? Give an example.

# %%
# Your answer here: 
text = "Hello123"
print(text.isalnum())
# Out:
# True

# %% [markdown]
# 28.  How do you check in a string that all characters are in lowercase? Give an example.

# %%
# Your answer here: 
text = "hello world"
print(text.islower())
# Out:
# True

# %% [markdown]
# 29. How do you check in a string that all characters are not numbers. Give an example.

# %%
# Your answer here: 
text = "Hello"
print(text.isalpha())
# Out:
# True

# %% [markdown]
# 30.  How do you get the length of the string? Give an example.

# %%
# Your answer here: 
text = "123456"
length = len(text)
print(length)
# Out:
# 6

# %% [markdown]
# 31.  How do you convert a string to all lowercase? Give an example.

# %%
# Your answer here: 
text = "HELLO WORLD"
text = text.lower()
print(text)
# Out:
# hello world

# %% [markdown]
# 32. How do you remove all leading whitespace in string? Give an example.

# %%
# Your code here:
text = "   Hello World"
text = text.lstrip()
print(text)
# Out:
# Hello World

# %% [markdown]
# 33.  There is a wikipedia package for Python! It makes it super easy to collect and parse entries. Install it and print a summary of the Marquis de Lafayette in French.

# %%
# Your code here:
# !pip install wikipedia
import wikipedia
wikipedia.set_lang("fr")
results = wikipedia.search("Marquis de Lafayette")
print(results)
print(wikipedia.summary(results[0]))
# Out:
# ...
# ['Gilbert du Motier de La Fayette', 'Lafayette Square (Washington)', 'Lafayette', 'James Armistead Lafayette', 'Visite du marquis de La Fayette aux États-Unis', 'Théodore Pellerin', 'Madame de La Fayette', 'Magnétisme animal', 'Angelica Schuyler Church', 'Hamilton (comédie musicale)']
# Gilbert du Motier, marquis de La Fayette, né le 6 septembre 1757 au château de Chavaniac près de Saint-Georges-d'Aurac (Auvergne, actuel département de la Haute-Loire), et mort le 20 mai 1834 à Paris (ancien 1er arrondissement), est un officier et homme politique français, célèbre en raison de son engagement dans les rangs de l'armée des insurgés américains (1777-1783), puis dans l'aile libérale et réformiste de l'aristocratie française (1784-1792), enfin dans l'opposition libérale au régime de la monarchie de Juillet qu'il avait pourtant contribué à établir lors des Trois Glorieuses (juillet 1830).
# ...

# %%
34 #Write code, usting the strip method, to remove the unecessary characters, and add a space to print Jackson Python

jackson_string = "grrrrr....ughhhh..JacksonPython@@@!!!!"
cleaned = jackson_string.strip("gruh.@!")
cleaned = cleaned.replace("Python", " Python")
print(cleaned)
# Out:
# Jackson Python

# %% [markdown]
# 35. Copy and paste your AI chat log here. If you didn't use AI let me know that, instead!

# %% [markdown]
# Your chat log here:

# %%
What is the operator in python to find the remainder of two numbers divided

The % operator (modulo operator) returns the remainder of division. Example: 10 % 3 returns 1, 15 % 4 returns 3, 20 % 5 returns 0. Common uses include checking if a number is even (number % 2 == 0) or odd (number % 2 == 1).

---

what is the operator to square something in python?

The ** operator is used for exponentiation. To square: 5 ** 2 returns 25. Other powers: 2 ** 3 returns 8, 9 ** 0.5 returns 3.0 (square root). Alternative: x * x or pow(x, 2).

---

Why is this returning false? .3 + .3 + .3 == .9

This returns False because of floating-point precision errors. .3 + .3 + .3 actually equals 0.8999999999999999, not exactly 0.9. Fix with: round(.3 + .3 + .3, 1) == .9 or use math.isclose(.3 + .3 + .3, .9).

---

python function for converting text to uppercase

The .upper() method converts text to uppercase. Example: "hello world".upper() returns "HELLO WORLD". Related methods: .lower() for lowercase, .capitalize() for first letter only, .title() for first letter of each word.

---

How would I make all vowels capitalized and all consonants lowercase in a string?

Use: result = "".join(char.upper() if char.lower() in "aeiou" else char.lower() for char in text if char.isalpha() or char + char). Example: "Hello World" becomes "hEllO wOrld".

---

how does the strip() method work?

.strip() removes whitespace (or specified characters) from both the beginning and end of a string. Example: "   Hello World   ".strip() returns "Hello World". Remove specific characters: "!!!Hello!!!".strip("!") returns "Hello". Related: .lstrip() removes from left only, .rstrip() removes from right only.

---

how to convert a string to a list in python

Use .split() method. Basic: "Hello world".split() returns ['Hello', 'world']. Split by character: "apple,banana".split(",") returns ['apple', 'banana']. Individual characters: list("Hello") returns ['H', 'e', 'l', 'l', 'o'].

---

what is a tuple and how do you convert a string a tuple

A tuple is an immutable ordered collection. Convert string to tuple: tuple("Hello") returns ('H', 'e', 'l', 'l', 'o'). For words: tuple("a b c".split()) returns ('a', 'b', 'c'). Tuples can't be changed after creation unlike lists.

---

how to capitalize the first letter of a string

Use .capitalize() method. Example: "hello world".capitalize() returns "Hello world". Note: makes first letter uppercase and all others lowercase. Related: .title() capitalizes first letter of each word, .upper() for all uppercase.

---

how do you remove leading white spaces in a string, is it the strip() method?

Use .lstrip() to remove leading (left side) whitespace only. .strip() removes from both sides. Example: "   Hello   ".lstrip() returns "Hello   ". .rstrip() removes right side only. .strip() removes both sides.

---

How would I approach this: 33. There is a wikipedia package for Python! It makes it super easy to collect and parse entries. Install it and print a summary of the Marquis de Lafayette in French.

Install with: !pip install wikipedia. Then: import wikipedia, wikipedia.set_lang("fr"), print(wikipedia.summary("Marquis de Lafayette")). If error, try: results = wikipedia.search("Lafayette"), print(wikipedia.summary(results[0])).

---

what would me strip function look like to clean this? jackson_string = "grrrrr....ughhhh..JacksonPython@@@!!!!"

cleaned = jackson_string.strip("gruh.@!").replace("Python", " Python") returns "Jackson Python". First strips unwanted characters from edges, then adds space before Python.

---

how does the strip("gruh.@!") function work exactly?

.strip("gruh.@!") removes any of those characters from both ends repeatedly until it hits a character not in that set. From left: removes g, r, u, h, . until hitting J. From right: removes !, @, . until hitting n. Only removes from edges, not middle. Order in the string doesn't matter.
